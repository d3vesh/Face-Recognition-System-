# %%
#Import the necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
#Read in the image using the imread function
# Taking the image of a monkey used in every face detection beginner tutorial
img_raw = cv2.imread("D:\_User's Documents\Deepthi Poojary\Desktop\Sensors\imagem.png")

# %%
# The type of the array
type(img_raw)
# Out:
# numpy.ndarray

# %%
# The shape of the array
img_raw.shape
# Out:
# (288, 288, 3)

# %%
# viewing the image 
plt.imshow(img_raw)

# %% [markdown]
# #### What we get as an output is a bit different concerning color. We expected a bright colored image but what we obtain is an image with some bluish tinge. That happens because OpenCV and matplotlib have different orders of primary colors. Whereas OpenCV reads images in the form of BGR, matplotlib, on the other hand, follows the order of RGB. Thus, when we read a file through OpenCV, we read it as if it contains channels in the order of blue, green and red. However, when we display the image using matplotlib, the red and blue channel gets swapped and hence the blue tinge. To avoid this issue, we will transform the channel to how matplotlib expects it to be using the cvtColor function.

# %%
img = cv2.cvtColor(img_raw,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %% [markdown]
# ## Drawing Exercise on blank image
# This exercise will help to draw on image. Which can be used to draw shapes on detected face.

# %%
image_blank = np.zeros(shape = (512,512,3),dtype = np.int16)
plt.imshow(image_blank)

# %% [markdown]
# ### Format
# var = cv2.shape(image,(Bottom Left part of shape),(Top Right part of shape),(R,G,B),line_thickness)

# %%
red_line = cv2.line(image_blank,(50,50),(450,450),(255,0,0),5)    
green_line = cv2.line(image_blank,(50,450),(200,250),(0,255,0),5)
blue_rectangle = cv2.rectangle(image_blank,(50,50),(450,450),(0,0,255),5)
circle_rgb = cv2.circle(image_blank,(250,250),(200),(0,0,255),5)
plt.imshow(red_line)

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
text = cv2.putText(image_blank,'Devesh',(10,500), font, 2,(255,255,255),10,cv2.LINE_AA)
# var = cv2.putText(image,'Text',(lower left cordinate),font style,font size,(R,G,B),thickness,cv2.linetype)
plt.imshow(text)

# %%
# loading image
test_image = cv2.imread("D:\_User's Documents\Deepthi Poojary\Desktop\Sensors\MUteam.png")
#Converting to grayscale
test_image_grayscale = cv2.cvtColor(test_image,cv2.COLOR_BGR2GRAY)
# Showing gray image
plt.imshow(test_image_grayscale,cmap = 'gray')

# %%
# Function to change BGR to RGB
def convert_BGR2RGB(image):
    return cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %% [markdown]
# Haar cascade classifier is one of hte most used classifier in open CV

# %%
haar_cascade_face = cv2.CascadeClassifier(r"C:\Users\Deepthi Poojary\haarcascade_frontalface_default.xml")

# %%
faces_rects = haar_cascade_face.detectMultiScale(test_image_grayscale,scaleFactor = 1.2,minNeighbors = 5)
# Number of faces found
print('Faces found: ',len(faces_rects))

# %%
# Drawing rectangle
for (x,y,w,h) in faces_rects:
        imag = cv2.rectangle(test_image,(x,y),(x+w,y+h),(0,255,0),5)  
plt.imshow(converttoRGB(imag))

# %%
# Function to do everything
def convert_BGR2GRAY(cascade,img):
    # Create a copy of image
    image = img.copy()
    # Convert into gray image
    gray_scale_image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    #plt.imshow(gray_scale_image,cmap = "gray")
    # Use cascading of gray image
    face_val = cascade.detectMultiScale(gray_scale_image,scaleFactor = 1.2,minNeighbors = 5)
    print(len(face_val))
    
    # Draw rectangle
    for (x,y,w,h) in face_val:
        imag = cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,0),2)
#     cv2.imshow("Champions",imag)
#     cv2.waitKey()
#     cv2.destroyAllWindows()
    return imag

# Function to convert BGR to RGB 
def converttoRGB(img):
    return cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
# Call function 
face = convert_BGR2GRAY(haar_cascade_face,test_image1)

# Convert image to RGB and plot
plt.imshow(converttoRGB(face))
